# %% [markdown]
# # Chapitre 4 - Tuple et Tableau

# %% [markdown]
# **Exercice 7 :**

# %% [markdown]
# Écrire une fonction `produit(nombres,n)` qui prend en paramètres un tableau de nombres nombres et un entier naturel non nul `n` et renvoie un nouveau tableau obtenue en multipliant chaque élément du tableau nombres par `n`.

# %%
def produit(nombres,n):
    taille = len(nombres)
    T = [0]*taille
    for i in range(taille):
       T[i] = nombres[i]*n
    return T

# %%
produit([1,5,8,45,32],666)
# Out:
# [666, 3330, 5328, 29970, 21312]

# %% [markdown]
# Et par compréhension ???

# %%
def produit_v2(nombres,n):
    return [element*n for element in nombres]

# %%
produit_v2([1,5,8,45,32],666)
# Out:
# [666, 3330, 5328, 29970, 21312]
