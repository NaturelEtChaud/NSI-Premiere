# %% [markdown]
# # Tout ce que je dois savoir de Python
# (1ère partie - Les bases)

# %% [markdown]
# ## 1) Je sais effectuer des opérations de bases

# %%
somme = 2+3
difference = 2-3
multiplication = 2*3
division = 2/3
division_entiere = 2//3
reste_division_entiere = 2%3
puissance = 2**3

# %% [markdown]
# ## 2) Je sais les types

# %%
a = 2           #a est un entier                 integer
b = 2.3         #b est flottant                  float
c = 'azerty'    #c est une chaîne de caractères  string
d = True        #d est un booléen                boolean
#on peut convertir d'un type à l'autre tant que ça a du sens
e = str(2)      # donc e contient '2'
f = int(2.3)    # donc f contient 2
g = float(2)    # donc g contient 2. sous entendu 2.0
h = int('2')    # dont h contient 2
