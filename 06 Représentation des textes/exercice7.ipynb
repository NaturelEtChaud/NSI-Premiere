# %% [markdown]
#  # Chapitre 5 - Représentation des textes

# %% [markdown]
# **Exercice 7**
#
# Écrire une fonction `occurrence(chaine,car)` qui prend en argument `chaine` une chaîne de caractères et `car` un caractère.
# Elle devra retourner le nombre de caractère égaux à `car` dans `chaine`.
# Par exemple `occurrence("un premier essai",'e')` devra retourner 3.

# %%
def occurrence(chaine,car) :
    compteur = 0
    chaine = chaine.lower()
    car = car.lower()
    for element in chaine :
        if element == car:
            compteur = compteur + 1
    return compteur

# %%
occurrence("un premier essai",'e')
# Out:
# 3
