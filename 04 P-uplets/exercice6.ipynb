# %% [markdown]
# # Chapitre 4 - Tuple et Tableau

# %% [markdown]
# **Exercice 6 :**
#
# Dans cet exercice, le but est de reprendre les questions de l'exercice 5, en utilisant cette fois-ci la construction des tableaux par compréhension.

# %% [markdown]
# 1. Écrire une fonction `multiples1(n)` qui prend en paramètre un entier naturel non nul `n` et renvoie un tableau contenant les 10 premiers multiples non nuls de `n`.

# %%
def multiples1(n):
    return [n*i for i in range(1,11)]

# %%
multiples1(66)
# Out:
# [66, 132, 198, 264, 330, 396, 462, 528, 594, 660]

# %% [markdown]
# 2. Écrire une fonction `multiples2(n)` qui prend en paramètre un entier naturel non nul `n` et renvoie un tableau contenant la liste des multiples de `n` inférieurs strictement à 1000.

# %%
def multiples2(n):
    return [n*i for i in range(1000//n)]

# %%
multiples2(66)
# Out:
# [0, 66, 132, 198, 264, 330, 396, 462, 528, 594, 660, 726, 792, 858, 924]

# %% [markdown]
# 3. Écrire une fonction `diviseurs(n)` qui prend en paramètre un entier naturel non nul `n` et renvoie un tableau contenant la liste des diviseurs de `n`.
#
# *(On constate que ne pas connaître le nombre de diviseurs a priori n'est plus un problème)*

# %%
def diviseurs(n):
    return [i for i in range(1,n+1) if n%i == 0]

# %%
diviseurs(66)
# Out:
# [1, 2, 3, 6, 11, 22, 33, 66]
